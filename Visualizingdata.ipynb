# %% [markdown]
# # Assignments: Visualizing Data

# %% [markdown]
# ## Read in the data

# %%
import pandas as pd

songs = pd.read_csv('../Data/spotify_songs.csv')
songs.head()
# Out:
#                            name       artists  energy  key  mode  valence  \
# 0                    God's Plan         Drake   0.449    7     1    0.357
# 1                          SAD!  XXXTENTACION   0.613    8     1    0.473
# 2    rockstar (feat. 21 Savage)   Post Malone   0.535    5     0    0.140
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone   0.559    8     1    0.439
# 4                In My Feelings         Drake   0.626    1     1    0.350
#
#      tempo  duration_ms
# 0   77.169       198973
# 1   75.023       166606
# 2  159.847       218147
# 3  140.124       221440
# 4   91.030       217925

# %%
songs.shape
# Out:
# (100, 8)

# %%
songs.describe()
# Out:
#            energy         key        mode     valence       tempo  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.659060    5.330000    0.590000    0.484443  119.904180
# std      0.145067    3.676447    0.494311    0.206145   28.795984
# min      0.296000    0.000000    0.000000    0.079600   64.934000
# 25%      0.562000    1.750000    0.000000    0.341000   95.730750
# 50%      0.678000    5.000000    1.000000    0.470500  120.116000
# 75%      0.772250    8.250000    1.000000    0.641500  140.022750
# max      0.909000   11.000000    1.000000    0.931000  198.075000
#
#          duration_ms
# count     100.000000
# mean   205206.780000
# std     40007.893404
# min     95467.000000
# 25%    184680.000000
# 50%    205047.500000
# 75%    221493.250000
# max    417920.000000

# %% [markdown]
# ## Distributions

# %% [markdown]
# Hi,
#
# Our music analysis team has labeled 100 songs with their musical attributes, such as its danceability and energy. Can you tell us more about the distributions of the musical attributes? I’m guessing that since most of the musical attributes are numeric, they should be normally distributed, but let me know if you see otherwise.
#
# Thanks!\
# Sarah

# %% [markdown]
# ### Interpret the histograms
#
# [Musical attribute definitions](https://developer.spotify.com/documentation/web-api/reference/get-audio-features)
#
# * Fields with normal distributions:
# * Fields with other distributions:
# * Skewed fields:
# * Outliers:
# * Other observations:
# * Do your interpretations make sense?

# %%
# Import the seaborn library
import seaborn as sns

# %%
songs['mode'].value_counts()
songs['key'].value_counts().sort_index()
songs['energy'].round().value_counts().sort_index()
# Out:
# energy
# 0.0    13
# 1.0    87
# Name: count, dtype: int64

# %%
# Create a pair plot
sns.pairplot(songs)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#valence and duration_ms is normally distributed. There seem to be 2 outliers in duration. 
#energy also seem to be somewhat normal, but the distribution seems left skewed. 
# valence and energy seems to be +vely related
#mode is discreet, only has two values
#key is also discreet

# %%
sns.histplot(songs['tempo'])
# Out:
# <Axes: xlabel='tempo', ylabel='Count'>

# %%
songs['tempo'].round(-1).value_counts()
# Out:
# tempo
# 100.0    19
# 90.0     16
# 120.0    12
# 130.0    12
# 140.0    10
# 150.0     7
# 110.0     6
# 80.0      5
# 180.0     4
# 160.0     3
# 170.0     3
# 60.0      1
# 200.0     1
# 190.0     1
# Name: count, dtype: int64

# %% [markdown]
# ## Correlations

# %% [markdown]
# Hi again,
#
# Thanks for looking into those distributions earlier. Can you also tell us more about the correlations of the musical attributes?
# Can you tell us about any relationships you can find in the data between the attributes, like if some are positively or negatively correlated?
#
# Thanks!\
# Sarah

# %% [markdown]
# ### Interpret the scatter plots
#
# [Musical attribute definitions](https://developer.spotify.com/documentation/web-api/reference/get-audio-features)
#
# * Highly correlated:
# * Uncorrelated:
# * Positive correlation:
# * Negative correlation:
# * Other observations:
# * Do your interpretations make sense?

# %%
songs[['energy','key','mode','valence','tempo','duration_ms']].corr()
# Out:
#                energy       key      mode   valence     tempo  duration_ms
# energy       1.000000 -0.136345 -0.117555  0.382434  0.062272     0.073017
# key         -0.136345  1.000000 -0.141568 -0.032622  0.003737     0.046144
# mode        -0.117555 -0.141568  1.000000 -0.210599 -0.011911     0.055411
# valence      0.382434 -0.032622 -0.210599  1.000000 -0.148423    -0.131901
# tempo        0.062272  0.003737 -0.011911 -0.148423  1.000000     0.005493
# duration_ms  0.073017  0.046144  0.055411 -0.131901  0.005493     1.000000

# %%
#valence and energy seem to have the highest correlation.
#lowest correlation: tempo and key

# %%
sns.pairplot(songs)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
